# %% [markdown]
# <a href="https://colab.research.google.com/github/fikarrizkip/Projects/blob/main/Implementasi_Decision_Tree_Dengan_Random_Forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **IMPLEMENTASI DECISION TREE DENGAN RANDOM FOREST**

# %% [markdown]
# Pohon keputusan (decision tree) merupakan salah satu algoritma machine learning yang populer dan mudah dipahami. Algoritma ini bekerja dengan membagi data menjadi beberapa subset berdasarkan aturan yang ditentukan. Namun, pohon keputusan memiliki keterbatasan, salah satunya adalah kecenderungan untuk overfitting, di mana model terlalu fokus pada data pelatihan dan tidak dapat digeneralisasikan dengan baik pada data baru.
#
# Di sinilah peran Random Forest hadir. Algoritma ini menggabungkan banyak pohon keputusan yang dibuat secara acak untuk menghasilkan prediksi yang lebih akurat dan stabil. Random Forest mampu mengatasi kelemahan pohon keputusan dan meningkatkan performa model secara keseluruhan. Berikut ini langkah-langkah implementasi decision tree dengan random forest.

# %%
#mengimport library Pandas
import pandas as pd
pd.set_option('display.max_column', 20)

#membaca dataset credit_scoring_dqlab dari file excel
df_credit_scoring = pd.read_excel('https://storage.googleapis.com/dqlab-dataset/credit_scoring_dqlab.xlsx')
print(df_credit_scoring.head())
# Out:
#   kode_kontrak  pendapatan_setahun_juta kpr_aktif  durasi_pinjaman_bulan  \
# 0   AGR-000001                      295        YA                     48
# 1   AGR-000011                      271        YA                     36
# 2   AGR-000030                      159     TIDAK                     12
# 3   AGR-000043                      210        YA                     12
# 4   AGR-000049                      165     TIDAK                     36
#
#    jumlah_tanggungan rata_rata_overdue  risk_rating
# 0                  5      61 - 90 days            4
# 1                  5      61 - 90 days            4
# 2                  0       0 - 30 days            1
# 3                  3      46 - 60 days            3
# 4                  0      31 - 45 days            2

# %%
#mengubah data kpr_aktif menjadi tipe integer: 'YA' = 1 dan 'TIDAK' = 0
df_credit_scoring['kpr_aktif'].replace(['YA', 'TIDAK'], [1, 0], inplace=True)
print(df_credit_scoring.head())
# Out:
#   kode_kontrak  pendapatan_setahun_juta  kpr_aktif  durasi_pinjaman_bulan  \
# 0   AGR-000001                      295          1                     48
# 1   AGR-000011                      271          1                     36
# 2   AGR-000030                      159          0                     12
# 3   AGR-000043                      210          1                     12
# 4   AGR-000049                      165          0                     36
#
#    jumlah_tanggungan rata_rata_overdue  risk_rating
# 0                  5      61 - 90 days            4
# 1                  5      61 - 90 days            4
# 2                  0       0 - 30 days            1
# 3                  3      46 - 60 days            3
# 4                  0      31 - 45 days            2

# %%
#Label Encoding rata_rata_overdue , untuk menghilangkan value string, sehingga bisa dibuat dalam bentuk numeric array, dan tidak error saat membuat modelnya
df_credit_scoring['rata_rata_overdue'].replace({
	'0 - 30 days':1,
	'31 - 45 days':2,
	'46 - 60 days':3,
	'61 - 90 days':4,
	'> 90 days':5
}, inplace=True)

print(df_credit_scoring.head())
# Out:
#   kode_kontrak  pendapatan_setahun_juta  kpr_aktif  durasi_pinjaman_bulan  \
# 0   AGR-000001                      295          1                     48
# 1   AGR-000011                      271          1                     36
# 2   AGR-000030                      159          0                     12
# 3   AGR-000043                      210          1                     12
# 4   AGR-000049                      165          0                     36
#
#    jumlah_tanggungan  rata_rata_overdue  risk_rating
# 0                  5                  4            4
# 1                  5                  4            4
# 2                  0                  1            1
# 3                  3                  3            3
# 4                  0                  2            2

# %% [markdown]
# **Membuat Variabel Independen dan Dependen**

# %% [markdown]
# Untuk X (independent variables), data yang dimasukkan semua persyaratan untuk membuat risk_rating (dependent variable), tidak memerlukan kode_kontrak. Selain itu rata_rata_overdue juga dikeluarkan karena merupakan transformasi numerik dari risk_rating sehingga kolom kode_kontrak, rata_rata_overdue dan risk_rating dibuang

# %%
X = df_credit_scoring.drop(columns=['kode_kontrak', 'risk_rating', 'rata_rata_overdue']).values
print('Ukuran varibel independen X: ', X.shape)
# Out:
# Ukuran varibel independen X:  (900, 4)

# %% [markdown]
# Untuk y (target/dependent variable) adalah target nilai yang harus dibuat sistem ketika membaca data X isinya adalah kolom risk_rating

# %%
y = df_credit_scoring['risk_rating'].values
print('Ukuran varibel dependen y: ', y.shape)
# Out:
# Ukuran varibel dependen y:  (900,)

# %% [markdown]
# **Membagi Data Training dan Data Testing**

# %%
#membagi data training dan data testing, di mana training 70% dan testing 30%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

#menampilkan jumlah data train dan test
print('Shape of X_train:', X_train.shape)
print('Shape of X_test :', X_test.shape)
print('Shape of y_train:', y_train.shape)
print('Shape of y_test :', y_test.shape)
# Out:
# Shape of X_train: (630, 4)
# Shape of X_test : (270, 4)
# Shape of y_train: (630,)
# Shape of y_test : (270,)

# %% [markdown]
# **Membuat Model**

# %%
#membangun model
from sklearn.tree import DecisionTreeClassifier

#Fit the classifier with default hyper-parameters
clf = DecisionTreeClassifier(random_state=1234)
clf.fit(X_train, y_train)

#menampilkan struktur decision tree
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.tree import plot_tree

feature_names = ['pendapatan_setahun_juta', 'kpr_aktif', 'durasi_pinjaman', 'jumlah_tanggungan']

target_names = df_credit_scoring['risk_rating'].unique().tolist()

target_names=[str(x) for x in target_names]

fig = plt.figure(figsize=(25,20))
plot_tree(clf,
          feature_names=feature_names,
          class_names=target_names,
          filled=True)
plt.tight_layout()
plt.show()

# %%
#menampilkan struktur decision tree dalam bentuk teks
from sklearn import tree
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_1 <= 0.50
# |   |--- feature_2 <= 30.00
# |   |   |--- feature_0 <= 145.00
# |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |--- feature_0 <= 137.00
# |   |   |   |   |   |--- feature_0 <= 88.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- feature_0 >  88.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  137.00
# |   |   |   |   |   |--- feature_2 <= 18.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- feature_2 >  18.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |--- feature_0 <= 110.00
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_0 >  110.00
# |   |   |   |   |   |--- feature_2 <= 18.00
# |   |   |   |   |   |   |--- feature_0 <= 140.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  140.50
# |   |   |   |   |   |   |   |--- feature_0 <= 141.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- feature_0 >  141.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  18.00
# |   |   |   |   |   |   |--- feature_0 <= 130.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_0 >  130.50
# |   |   |   |   |   |   |   |--- feature_0 <= 132.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  132.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 133.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  133.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 134.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  134.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_3 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |--- feature_0 >  145.00
# |   |   |   |--- feature_3 <= 2.50
# |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |--- feature_0 <= 175.00
# |   |   |   |   |   |   |--- feature_0 <= 154.00
# |   |   |   |   |   |   |   |--- feature_0 <= 152.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  152.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 18.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- feature_2 >  18.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  154.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  175.00
# |   |   |   |   |   |   |--- feature_0 <= 194.00
# |   |   |   |   |   |   |   |--- feature_0 <= 182.00
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- feature_0 >  182.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 188.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  188.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 192.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  192.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 18.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  18.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  194.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  2.50
# |   |   |   |   |--- feature_3 <= 4.50
# |   |   |   |   |   |--- feature_3 <= 3.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |--- feature_3 >  3.50
# |   |   |   |   |   |   |--- feature_0 <= 171.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  171.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_3 >  4.50
# |   |   |   |   |   |--- class: 1
# |   |--- feature_2 >  30.00
# |   |   |--- feature_2 <= 42.00
# |   |   |   |--- feature_0 <= 202.00
# |   |   |   |   |--- feature_0 <= 101.00
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_0 >  101.00
# |   |   |   |   |   |--- feature_0 <= 191.00
# |   |   |   |   |   |   |--- feature_0 <= 116.00
# |   |   |   |   |   |   |   |--- feature_0 <= 102.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |--- feature_3 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  102.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  116.00
# |   |   |   |   |   |   |   |--- feature_0 <= 186.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 138.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 121.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  121.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  138.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 143.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  143.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 148.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  148.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- feature_0 >  186.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  191.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- feature_0 >  202.00
# |   |   |   |   |--- class: 1
# |   |   |--- feature_2 >  42.00
# |   |   |   |--- feature_3 <= 4.00
# |   |   |   |   |--- feature_0 <= 210.00
# |   |   |   |   |   |--- feature_0 <= 91.50
# |   |   |   |   |   |   |--- feature_0 <= 90.00
# |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 86.00
# |   |   |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |   |   |   |--- feature_0 >  86.00
# |   |   |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_0 >  90.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  91.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_0 >  210.00
# |   |   |   |   |   |--- feature_0 <= 219.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  219.00
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |--- feature_3 >  4.00
# |   |   |   |   |--- feature_0 <= 189.50
# |   |   |   |   |   |--- feature_0 <= 117.50
# |   |   |   |   |   |   |--- feature_0 <= 80.50
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |   |   |--- feature_0 >  80.50
# |   |   |   |   |   |   |   |--- feature_0 <= 99.00
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- feature_0 >  99.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  117.50
# |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_0 >  189.50
# |   |   |   |   |   |--- class: 1
# |--- feature_1 >  0.50
# |   |--- feature_3 <= 4.50
# |   |   |--- feature_3 <= 0.50
# |   |   |   |--- feature_0 <= 106.00
# |   |   |   |   |--- feature_0 <= 71.50
# |   |   |   |   |   |--- class: 4
# |   |   |   |   |--- feature_0 >  71.50
# |   |   |   |   |   |--- feature_0 <= 75.00
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_0 >  75.00
# |   |   |   |   |   |   |--- class: 4
# |   |   |   |--- feature_0 >  106.00
# |   |   |   |   |--- class: 3
# |   |   |--- feature_3 >  0.50
# |   |   |   |--- feature_0 <= 166.50
# |   |   |   |   |--- class: 3
# |   |   |   |--- feature_0 >  166.50
# |   |   |   |   |--- feature_0 <= 167.50
# |   |   |   |   |   |--- feature_3 <= 2.50
# |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_3 >  2.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  167.50
# |   |   |   |   |   |--- feature_3 <= 1.50
# |   |   |   |   |   |   |--- feature_2 <= 42.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  42.00
# |   |   |   |   |   |   |   |--- class: 3
# |   |   |   |   |   |--- feature_3 >  1.50
# |   |   |   |   |   |   |--- class: 3
# |   |--- feature_3 >  4.50
# |   |   |--- feature_2 <= 30.00
# |   |   |   |--- feature_0 <= 192.50
# |   |   |   |   |--- feature_0 <= 188.00
# |   |   |   |   |   |--- feature_0 <= 94.50
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_0 >  94.50
# |   |   |   |   |   |   |--- feature_0 <= 127.00
# |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |--- feature_0 >  127.00
# |   |   |   |   |   |   |   |--- feature_0 <= 129.00
# |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- feature_0 >  129.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 18.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 175.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 163.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  163.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  175.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- feature_2 >  18.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 145.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  145.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |--- feature_0 >  188.00
# |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |--- feature_0 >  192.50
# |   |   |   |   |--- class: 4
# |   |   |--- feature_2 >  30.00
# |   |   |   |--- feature_0 <= 250.50
# |   |   |   |   |--- feature_0 <= 111.50
# |   |   |   |   |   |--- feature_0 <= 106.00
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_0 >  106.00
# |   |   |   |   |   |   |--- feature_2 <= 42.00
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |--- feature_2 >  42.00
# |   |   |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_0 >  111.50
# |   |   |   |   |   |--- feature_2 <= 42.00
# |   |   |   |   |   |   |--- feature_0 <= 205.50
# |   |   |   |   |   |   |   |--- feature_0 <= 197.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |--- feature_3 >  5.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 156.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  156.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 157.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  157.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |   |   |--- feature_0 >  197.50
# |   |   |   |   |   |   |   |   |--- class: 4
# |   |   |   |   |   |   |--- feature_0 >  205.50
# |   |   |   |   |   |   |   |--- class: 5
# |   |   |   |   |   |--- feature_2 >  42.00
# |   |   |   |   |   |   |--- class: 5
# |   |   |   |--- feature_0 >  250.50
# |   |   |   |   |--- class: 4

# %% [markdown]
# **Menerapkan Random Forest**

# %%
#membangun Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

#Entropy controls how a Decision Tree decides to split the data. It actually affects how a Decision Tree draws its boundaries. random_state digunakan untuk menentukan jumlah bootstrapping sample yang akan dilakukan popular random_state values are 0 and 42
rfc = RandomForestClassifier(criterion='entropy', random_state=42)
rfc.fit(X_train, y_train)
print('RandomForestClassifier:', rfc)

from sklearn.metrics import f1_score

#mengevaluasi data training
rfc_pred_train = rfc.predict(X_train)
print('Training Set Evaluation F1-Score:', f1_score(y_train, rfc_pred_train, average='micro'))

#mengevaluasi data testing
rfc_pred_test = rfc.predict(X_test)
print('Testing Set Evaluation F1-Score:', f1_score(y_test, rfc_pred_test, average='micro'))
# Out:
# RandomForestClassifier: RandomForestClassifier(criterion='entropy', random_state=42)
# Training Set Evaluation F1-Score: 0.9904761904761905
# Testing Set Evaluation F1-Score: 0.8740740740740742

# %% [markdown]
# **Conclusion**
#
#
# 1. Nilai F1-Score yang tinggi pada training set (dekat dengan 1.0) menunjukkan bahwa model klasifikasi telah belajar dengan baik dari data pelatihan. Model ini mampu mengklasifikasikan sebagian besar sampel training dengan sangat baik, dengan tingkat precision dan recall yang tinggi.
#
#
# 2. F1-Score yang lebih rendah pada testing set menunjukkan bahwa performa model saat diuji dengan data baru (yang tidak pernah dilihat sebelumnya) tidak sebaik saat diuji dengan data training namun masih layak digunakan.
